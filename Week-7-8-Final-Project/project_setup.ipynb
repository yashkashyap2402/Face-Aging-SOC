# %% [markdown]
# # Week 7 & 8 - Face Aging Final Project Setup
#
# This notebook describes the setup, workflow, required libraries, and project structure for the Face Aging Final Project. The goal is to build a complete face aging application that predicts an aged version of a person's face using an AI-based age progression model.

# %% [markdown]
# ## Project Objective
#
# The objective of this project is to develop a face aging application that takes a facial image as input and generates a realistic aged version while preserving the person's identity.
#
# The project includes image preprocessing, model inference, and comparison of the original and generated images.

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %% [markdown]
# ## Required Libraries
#
# The project uses the following Python libraries:
#
# - OpenCV
# - NumPy
# - Matplotlib
# - Pillow
# - PyTorch
# - TorchVision

# %%
libraries = [
    "OpenCV",
    "NumPy",
    "Matplotlib",
    "Pillow",
    "PyTorch",
    "TorchVision"
]

for lib in libraries:
    print(lib)
# Out:
# OpenCV
# NumPy
# Matplotlib
# Pillow
# PyTorch
# TorchVision

# %% [markdown]
# ## Project Workflow
#
# The project follows these steps:
#
# 1. Upload a face image.
# 2. Preprocess the image.
# 3. Load the face aging model.
# 4. Generate the aged face.
# 5. Save the generated image.
# 6. Compare the original and aged images.

# %%
workflow = [
    "Upload Image",
    "Preprocess Image",
    "Load Model",
    "Generate Aged Face",
    "Save Result",
    "Compare Images"
]

for step in workflow:
    print(step)
# Out:
# Upload Image
# Preprocess Image
# Load Model
# Generate Aged Face
# Save Result
# Compare Images

# %% [markdown]
# ## Folder Structure
#
# The project is organized into folders for better management of images, models, notebooks, and generated results.

# %%
project_structure = {
    "sample_images": "Stores input face images",
    "results": "Stores generated aged images",
    "models": "Stores trained model files",
    "notebooks": "Stores Google Colab notebooks"
}

for folder, description in project_structure.items():
    print(f"{folder} -> {description}")
# Out:
# sample_images -> Stores input face images
# results -> Stores generated aged images
# models -> Stores trained model files
# notebooks -> Stores Google Colab notebooks

# %% [markdown]
# ## Input
#
# The input to the model is a facial image uploaded by the user. The image is resized and preprocessed before being passed to the face aging model.

# %%
image_size = (128, 128)

print("Expected Image Size:", image_size)
# Out:
# Expected Image Size: (128, 128)

# %% [markdown]
# ## Output
#
# The output of the project is a generated facial image representing the predicted appearance of the same person at a different age.
#
# The generated image is saved for comparison with the original input image.

# %%
output_file = "aged_face.png"

print("Output File:", output_file)
# Out:
# Output File: aged_face.png

# %% [markdown]
# ## Applications
#
# Face aging models have several practical applications, including:
#
# - Age progression
# - Age regression
# - Missing person investigations
# - Forensic analysis
# - Entertainment and media
# - Digital avatar generation

# %%
applications = [
    "Age Progression",
    "Age Regression",
    "Forensic Investigation",
    "Entertainment",
    "Digital Avatars"
]

for app in applications:
    print(app)
# Out:
# Age Progression
# Age Regression
# Forensic Investigation
# Entertainment
# Digital Avatars

# %% [markdown]
# ## Expected Results
#
# The project should:
#
# - Accept a face image as input.
# - Generate an aged version of the face.
# - Preserve the identity of the person.
# - Produce realistic facial changes.
# - Display both original and generated images for comparison.

# %%
## Summary

In this notebook, we learned:

- Project objective
- Required libraries
- Project workflow
- Folder structure
- Input and output of the project
- Applications of face aging models
