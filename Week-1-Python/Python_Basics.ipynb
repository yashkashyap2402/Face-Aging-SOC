# %%
name = input("What is your name? ")
print("Hello " + name)
# Out:
# What is your name? yash
# Hello yash

# %%
x = 3 == 2
print(x)
# Out:
# False

# %%
price = 25
print( not price > 10)
# Out:
# False

# %%
temperature = 5
if temperature > 30:
    print("It's a hot day")
    print("Drink plenty of water")
elif temperature > 20:
    print("It's a nice day")
elif temperature > 10:
    print("It's a very nice day")
    print("It's a cold day")
else:
    print("It's cold")
print("Done")
# Out:
# It's cold
# Done

# %%
birth_year = input("Enter your birth year: ")
age = 2026 - int(birth_year)
print(age)
# Out:
# Enter your birth year: 2006
# 20

# %%
course = 'Python for Beginners'
print('Python' in course)
print(course)
# Out:
# True
# Python for Beginners

# %%
weight = input("Weight: ")
w = int(weight)
u = w/2.204623
unit = input("(K)g or (L)bs: ")
if unit == "K":
     print("Weight in Kg: ", w)
elif unit == "l":
     print("Weight in Kg: ", u )
else:
    print("-1")
# Out:
# Weight: 66
# (K)g or (L)bs: K
# Weight in Kg:  66

# %%
i = 1
while i <= 10:
    print((2*i -1 ) * "*")
    i = i+1
# Out:
# *
# ***
# *****
# *******
# *********
# ***********
# *************
# ***************
# *****************
# *******************

# %%
names = ["yash", "chirayu", "jefferson"]
names[0] = "adi"
print(names[0:3])
# Out:
# ['adi', 'chirayu', 'jefferson']

# %%
def square(x):
    return x * x

print(square(5))
print(square(10))
# Out:
# 25
# 100

# %%
student = {
    "name": "Yash",
    "age": 18,
    "branch": "Chemical"
}

print(student["name"])
print(student["branch"])
# Out:
# Yash
# Chemical

# %%
class Student:
    def __init__(self, name):
        self.name = name

    def greet(self):
        print("Hello,", self.name)

s1 = Student("Yash")
s1.greet()
# Out:
# Hello, Yash

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)
print(arr * 2)
print(arr + 10)
# Out:
# [1 2 3 4 5]
# [ 2  4  6  8 10]
# [11 12 13 14 15]
